# %% [markdown]
# ### Ejemplo de uso del  modelo de lenguaje pre entrenado y afinado con textos para niños.

# %% [markdown]
# ### Install dependencies

# %%
# !pip install transformers
# !pip install gradio
# Out:
# Collecting transformers
#   Downloading transformers-4.33.3-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.3
# Collecting gradio
#   Downloading gradio-3.46.0-py3-none-any.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 36.3 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.103.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 7.2 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.5.3 (from gradio)
#   Downloading gradio_client-0.5.3-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.4/298.4 kB 26.7 MB/s eta 0:00:00
# Collecting httpx (from gradio)
#   Downloading httpx-0.25.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.17.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.23.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.10.12)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.2 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.5.3->gradio) (2023.6.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (3.12.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 490.0 kB/s eta 0:00:00
# Collecting httpcore<0.19.0,>=0.18.0 (from httpx->gradio)
#   Downloading httpcore-0.18.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=0ff1318a863112d4294217a2f51a19365f1717fc1c4df1b60e761af3e317c106
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, semantic-version, python-multipart, orjson, h11, aiofiles, uvicorn, starlette, httpcore, httpx, fastapi, gradio-client, gradio
# Successfully installed aiofiles-23.2.1 fastapi-0.103.2 ffmpy-0.3.1 gradio-3.46.0 gradio-client-0.5.3 h11-0.14.0 httpcore-0.18.0 httpx-0.25.0 orjson-3.9.7 pydub-0.25.1 python-multipart-0.0.6 semantic-version-2.10.0 starlette-0.27.0 uvicorn-0.23.2 websockets-11.0.3

# %% [markdown]
# ### Load model checkpoint and tokenizer

# %%
from transformers import AutoTokenizer

# Load tokenizer

#checkpoint = "franfram/distillbert-base-spanish-uncased_finetuned_with-Llama2-Knowledge-Distillation"
checkpoint = "franfram/distillbert-base-spanish-uncased-finetuned-spanish-corpus"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)

vocab = tokenizer.get_vocab()
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/428 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/735k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %% [markdown]
# ### def get_pictograms

# %%
import pandas as pd

def get_pictograms(url):
  pictograms = pd.read_csv(url, header=None)[[1]].melt().value.tolist()
  return pictograms

url = "https://raw.githubusercontent.com/franfram/Transformers-nlp/main/pictograms_cleaned.csv"
pictograms = get_pictograms(url)
pictograms
# Out:
# ['0',
#  'peinar',
#  'cerrar',
#  'volar',
#  'buena',
#  'igual',
#  'nieve',
#  'moto',
#  'pescado',
#  'gracias',
#  'pis',
#  'suerte',
#  'amigo',
#  'caracol',
#  'tomate',
#  'bonito',
#  'lluvia',
#  'televisor',
#  'abrazar',
#  'artificiales',
#  'vidrio',
#  'parque',
#  'es',
#  'fanta',
#  'peluqueria',
#  'buenas',
#  'cama',
#  'trabajar',
#  'mediano',
#  'ya',
#  'noches',
#  'diario',
#  'museo',
#  'caminar',
#  'tienda',
#  'cafe',
#  'arco',
#  'coete',
#  'huerta',
#  'Psicología',
#  'naranja',
#  'carnaval',
#  'buzo',
#  'perder',
#  'estanteria',
#  'que',
#  'malla',
#  'collar',
#  'pene',
#  'avion',
#  'jugo',
#  'canguro',
#  'mano',
#  'mochila',
#  'te',
#  'hermano',
#  'caballo',
#  'colonia',
#  'raro',
#  'mosquito',
#  'toques',
#  'otoño',
#  'al',
#  'timbre',
#  'pera',
#  'molestar',
#  'pañal',
#  'foca',
#  'tronco',
#  'revista',
#  'cansado',
#  'mucho',
#  'ayudar',
#  'auto',
#  'queso',
#  'calzoncillo',
#  'donde',
#  'reducida',
#  'pollo',
#  'iris',
#  'frio',
#  'esperar',
#  'a',
#  'mes',
#  'invierno',
#  'levantarse',
#  'recordar',
#  'carton',
#  'tio',
#  'elefante',
#  'foto',
#  'rizado',
#  'circo',
#  'dinero',
#  'dar',
#  'lobo',
#  'atras',
#  'olvidar',
#  'anillo',
#  'plaza',
#  'ciudad',
#  'pileta',
#  'cocina',
#  'bajo',
#  'montaña',
#  'metal',
#  'grande',
#  'banana',
#  'derecha',
#  'adentro',
#  'habitacion',
#  'abeja',
#  'vecina',
#  'tortilla',
#  'llorar',
#  'ahora',
#  'tortuga',
#  'quien',
#  'sandia',
#  'sillon',
#  'calor',
#  'puente',
#  'nena',
#  'nervioso',
#  'calle',
#  'Musicoterapia',
#  'mi',
#  'claro',
#  'ducha',
#  'excursion',
#  'gimnasio',
#  'nene',
#  'pure',
#  'pelo',
#  'plantar',
#  'turno',
#  'tonteria',
#  'deporte',
#  'paraguas',
#  'cena',
#  'de',
#  'escalera',
#  'año',
#  'hospital',
#  'sal',
#  'sorprendido',
#  'arrancar',
#  'encendido',
#  'boca',
#  'mesa',
#  'peluche',
#  'plastico',
#  'volante',
#  'vender',
#  'nuevo',
#  'hola',
#  'raton',
#  'remera',
#  'clase',
#  'leon',
#  'cerezas',
#  'ballena',
#  'comunicador',
#  'asustado',
#  'gustar',
#  'Psicomotricista',
#  'pie',
#  'nubes',
#  'dolor',
#  'invitar',
#  'querer',
#  'mascara',
#  'ensalada',
#  'oreja',
#  'divertido',
#  'bueno',
#  'nadar',
#  'merienda',
#  'diferente',
#  'triste',
#  'mermelada',
#  'me',
#  'camilla',
#  'huevo',
#  'mañana',
#  'salchicha',
#  'gato',
#  'tobogan',
#  'primavera',
#  'volver',
#  'futbol',
#  'reir',
#  'largo',
#  'calendario',
#  'zapallo',
#  'torta',
#  'oler',
#  'chico',
#  'rio',
#  'para',
#  'vecinos',
#  'carpeta',
#  'ordenar',
#  'caramelo',
#  'ellos',
#  'silla',
#  'cocinar',
#  'manzana',
#  'ayer',
#  'caca',
#  'sucio',
#  'roto',
#  'lechuza',
#  'tardes',
#  'movilidad',
#  'mosca',
#  'romper',
#  'tarde',
#  'salado',
#  'corbata',
#  'pensar',
#  'magos',
#  'gritar',
#  'malo',
#  'control',
#  'bar',
#  'cuello',
#  'desvestir',
#  'luz',
#  'abuela',
#  'comida',
#  'lejos',
#  'buenos',
#  'ruta',
#  'gracioso',
#  'pintar',
#  'fuerte',
#  'dinosaurio',
#  'tal',
#  'tia',
#  'relampago',
#  'serpiente',
#  'muñeca',
#  'rompecabezas',
#  'conmutador',
#  'globo',
#  'gimnasia',
#  'pueblo',
#  'caer',
#  'cosa',
#  'bicicleta',
#  'escribir',
#  'mala',
#  'primero',
#  'aeropuerto',
#  'Ocupacional',
#  'pan',
#  'vestir',
#  'dibujar',
#  'rosa',
#  'corpiño',
#  'miedo',
#  'madera',
#  'salvavidas',
#  'rascar',
#  'pegar',
#  'coser',
#  'comprar',
#  'lado',
#  'seco',
#  'esta',
#  'gallina',
#  'pinchar',
#  'armario',
#  'tijera',
#  'abrir',
#  'arroz',
#  'hamaca',
#  'melon',
#  'aburrido',
#  'patio',
#  'casa',
#  'planta',
#  'bipedestador',
#  'boton',
#  'disfraz',
#  'mareado',
#  'cambiar',
#  'nada',
#  'Fonoaudiología',
#  'brazo',
#  'mojado',
#  'trueno',
#  'hueso',
#  'hallowen',
#  'pato',
#  'perro',
#  'dibujo',
#  'arriba',
#  'una',
#  'favor',
#  'mar',
#  'muñeco',
#  'regar',
#  'siento',
#  'mirar',
#  'cine',
#  'vecino',
#  'computadora',
#  'guantes',
#  'vaca',
#  'todo',
#  'estacionar',
#  'estudiar',
#  'delfin',
#  'llevar',
#  'mono',
#  'izquierda',
#  'ir',
#  'viento',
#  'campera',
#  'entiendo',
#  'playa',
#  'helicoptero',
#  'buen',
#  'ganar',
#  'Terapia',
#  'hotel',
#  'genial',
#  'pollito',
#  'oso',
#  'bosque',
#  'vestido',
#  'antes',
#  'con',
#  'lo',
#  'cuento',
#  'impresora',
#  'enfermo',
#  'oscuro',
#  'viejo',
#  'pala',
#  'cebra',
#  'amar',
#  'saber',
#  'como',
#  'espejo',
#  'fuego',
#  'impermeable',
#  'pronto',
#  'abuelo',
#  'rana',
#  'abrigo',
#  'pagar',
#  'noel',
#  'gemelos',
#  'correr',
#  'explicar',
#  'agenda',
#  'subte',
#  'lapiz',
#  'pierna',
#  'babero',
#  'tren',
#  'pajaro',
#  'zapatos',
#  'cerca',
#  'taller',
#  'sentarse',
#  'nosotros',
#  'caliente',
#  'esconder',
#  'contento',
#  'motor',
#  'manteca',
#  'cerdo',
#  'ventana',
#  'oveja',
#  'guardar',
#  'bajar',
#  'vagina',
#  'aprender',
#  'agua',
#  'encastrable',
#  'piedra',
#  'pelota',
#  'tractor',
#  'adios',
#  'botas',
#  'secar',
#  'iglesia',
#  'teatro',
#  'dedo',
#  'hacer',
#  'hablar',
#  'carne',
#  'paralisis',
#  'dormir',
#  'desayuno',
#  'lleno',
#  'pulsera',
#  'tambien',
#  'Pediatra',
#  'casamiento',
#  'hora',
#  'pasear',
#  'navidad',
#  'internet',
#  'accidente',
#  'afuera',
#  'pegamento',
#  'dia',
#  'papel',
#  'abuelos',
#  'tigre',
#  'restaurante',
#  'acuerdo',
#  'dientes',
#  'barco',
#  'conejo',
#  'horrible',
#  'tu',
#  'vacio',
#  'pizarron',
#  'abajo',
#  'regalo',
#  'subir',
#  'limpiar',
#  'pañuelo',
#  'feria',
#  'lentejas',
#  'flor',
#  'mate',
#  'embarazada',
#  'juguetes',
#  'farmacia',
#  'papa',
#  'cortar',
#  'araña',
#  'mujer',
#  'incomodo',
#  'hacemos',
#  'canelones',
#  'sol',
#  'feo',
#  'pincel',
#  'mercado',
#  'pez',
#  'mandarina',
#  'besar',
#  'Cardiologo',
#  'residencia',
#  'bicho',
#  'servicio',
#  'puerta',
#  'radio',
#  'cangrejo',
#  'delantal',
#  'gorro',
#  'cierre',
#  'enseñar',
#  'leche',
#  'mas',
#  'pizza',
#  'granja',
#  'uña',
#  'agarrar',
#  'lagartija',
#  'margarita',
#  'bufanda',
#  'baño',
#  'festejar',
#  'camisa',
#  'niebla',
#  'bombacha',
#  'Psiquiatra',
#  'liso',
#  'enojado',
#  'Kinesiología',
#  'sobre',
#  'llamas',
#  'beber',
#  'camion',
#  'duro',
#  'hierba',
#  'ardilla',
#  'rampa',
#  'leer',
#  'telefono',
#  'felicidades',
#  'comedor',
#  'mojar',
#  'gallo',
#  'ambulancia',
#  'se',
#  'libro',
#  'culo',
#  'pelear',
#  'estacion',
#  'bolso',
#  'lampara',
#  'reloj',
#  'pijama',
#  'frutilla',
#  'piel',
#  'descansar',
#  'tener',
#  'anteojos',
#  'plastilina',
#  'mariposa',
#  'sangre',
#  'carcel',
#  'maestra',
#  'blando',
#  'pizzeria',
#  'noche',
#  'cadera',
#  'cartas',
#  'saltar',
#  'mama',
#  'ojo',
#  'tostada',
#  'hoja',
#  'helado',
#  'ayuda',
#  'acostarse',
#  'cara',
#  'bolsa',
#  'lindo',
#  'apagado',
#  'cabeza',
#  'jugar',
#  'caja',
#  'cola',
#  'limon',
#  'joven',
#  'paciencia',
#  'adelante',
#  'yo',
#  'rapido',
#  'mellizos',
#  'cumpleaños',
#  'provecho',
#  'ascensor',
#  'verduras',
#  'sopa',
#  'remoto',
#  'ventilador',
#  'estoy',
#  'cuantos',
#  'bailar',
#  'vacaciones',
#  'musica',
#  'alto',
#  'luna',
#  'escondida',
#  'medias',
#  'tunel',
#  'cuando',
#  'nariz',
#  'videojuego',
#  'estacionamiento',
#  'limpio',
#  'verano',
#  'reyes',
#  'espalda',
#  'correo',
#  'escuchar',
#  'gusano',
#  'lento',
#  'dulce',
#  'buenisimo',
#  'quiero',
#  'coca',
#  'sirve',
#  'facil',
#  'cinto',
#  'canasta',
#  'por',
#  'menos',
#  'contar',
#  'no',
#  'biblioteca',
#  'otro',
#  'hamburguesa',
#  'despues',
#  'hoy',
#  'colectivo',
#  'ultimo',
#  'estas',
#  'piñata',
#  'dias',
#  'cantar',
#  'hermana',
#  'pintura',
#  'delgado',
#  'azucar',
#  'maestro',
#  'bañar',
#  'amiga',
#  'cancha',
#  'taxi',
#  'bien',
#  'fuegos',
#  'gusta',
#  'lengua',
#  'pantalones',
#  'rueda',
#  'poco',
#  'burro',
#  'escuela',
#  'rotonda',
#  'comisaria',
#  'corto',
#  'gordo',
#  'panaderia',
#  'Neurólogo',
#  'camping',
#  'raiz',
#  'hombre',
#  'camioneta',
#  'ruedas',
#  'cerebral',
#  'sortear',
#  'jirafa',
#  'arbol',
#  'poner',
#  'equivocado',
#  'entre',
#  'falda',
#  'flojo',
#  'Psicopedagogía',
#  'comer',
#  'tablero',
#  'cabra',
#  'llave',
#  'barriga',
#  'chaleco',
#  'dificil',
#  'niños']

# %%
len(pictograms)
# Out:
# 640

# %% [markdown]
# ### Test model

# %%
from transformers import pipeline
top_k = 200 #@param {type: "integer"}

unmasker = pipeline("fill-mask", model="franfram/distillbert-base-spanish-uncased_finetuned_with-Llama2-Knowledge-Distillation")
#unmasker = pipeline("fill-mask", model="google/mobilebert-uncased")
text = 'quiero comer un ' #@param {type: "string"}
text += ' [MASK]'

unmasked = unmasker(text, top_k=top_k)


unmasked
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/566 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/269M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/735k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [{'score': 0.10666672140359879,
#   'token': 11273,
#   'token_str': 'helado',
#   'sequence': 'quiero comer un helado'},
#  {'score': 0.07054208219051361,
#   'token': 28110,
#   'token_str': 'filete',
#   'sequence': 'quiero comer un filete'},
#  {'score': 0.0675901249051094,
#   'token': 12232,
#   'token_str': 'huevo',
#   'sequence': 'quiero comer un huevo'},
#  {'score': 0.06573796272277832,
#   'token': 8633,
#   'token_str': 'pastel',
#   'sequence': 'quiero comer un pastel'},
#  {'score': 0.047738898545503616,
#   'token': 9689,
#   'token_str': 'pollo',
#   'sequence': 'quiero comer un pollo'},
#  {'score': 0.04623118042945862,
#   'token': 10422,
#   'token_str': 'plato',
#   'sequence': 'quiero comer un plato'},
#  {'score': 0.03755443915724754,
#   'token': 1819,
#   'token_str': 'poco',
#   'sequence': 'quiero comer un poco'},
#  {'score': 0.03274385258555412,
#   'token': 9160,
#   'token_str': 'cerdo',
#   'sequence': 'quiero comer un cerdo'},
#  {'score': 0.024829993024468422,
#   'token': 14532,
#   'token_str': 'conejo',
#   'sequence': 'quiero comer un conejo'},
#  {'score': 0.02346923016011715,
#   'token': 18284,
#   'token_str': 'pavo',
#   'sequence': 'quiero comer un pavo'},
#  {'score': 0.018900321796536446,
#   'token': 8123,
#   'token_str': 'pez',
#   'sequence': 'quiero comer un pez'},
#  {'score': 0.01735527068376541,
#   'token': 16327,
#   'token_str': 'postre',
#   'sequence': 'quiero comer un postre'},
#  {'score': 0.01727616786956787,
#   'token': 8783,
#   'token_str': 'trago',
#   'sequence': 'quiero comer un trago'},
#  {'score': 0.016190610826015472,
#   'token': 27532,
#   'token_str': 'refresco',
#   'sequence': 'quiero comer un refresco'},
#  {'score': 0.014971960335969925,
#   'token': 9759,
#   'token_str': 'pescado',
#   'sequence': 'quiero comer un pescado'},
#  {'score': 0.014607168734073639,
#   'token': 10307,
#   'token_str': 'pedazo',
#   'sequence': 'quiero comer un pedazo'},
#  {'score': 0.014160783030092716,
#   'token': 21102,
#   'token_str': 'perrito',
#   'sequence': 'quiero comer un perrito'},
#  {'score': 0.013429529033601284,
#   'token': 4678,
#   'token_str': 'perro',
#   'sequence': 'quiero comer un perro'},
#  {'score': 0.011631920002400875,
#   'token': 15490,
#   'token_str': 'trozo',
#   'sequence': 'quiero comer un trozo'},
#  {'score': 0.009272828698158264,
#   'token': 10164,
#   'token_str': 'chocolate',
#   'sequence': 'quiero comer un chocolate'},
#  {'score': 0.00841306522488594,
#   'token': 8104,
#   'token_str': 'gato',
#   'sequence': 'quiero comer un gato'},
#  {'score': 0.008157291449606419,
#   'token': 17525,
#   'token_str': 'gusano',
#   'sequence': 'quiero comer un gusano'},
#  {'score': 0.007750221062451601,
#   'token': 9988,
#   'token_str': 'almuerzo',
#   'sequence': 'quiero comer un almuerzo'},
#  {'score': 0.00739945936948061,
#   'token': 2463,
#   'token_str': 'pan',
#   'sequence': 'quiero comer un pan'},
#  {'score': 0.006665628869086504,
#   'token': 24729,
#   'token_str': 'caramelo',
#   'sequence': 'quiero comer un caramelo'},
#  {'score': 0.005483557935804129,
#   'token': 6695,
#   'token_str': 'rato',
#   'sequence': 'quiero comer un rato'},
#  {'score': 0.005472972989082336,
#   'token': 3,
#   'token_str': '[UNK]',
#   'sequence': 'quiero comer un'},
#  {'score': 0.00544557673856616,
#   'token': 12321,
#   'token_str': 'poquito',
#   'sequence': 'quiero comer un poquito'},
#  {'score': 0.005375211592763662,
#   'token': 9124,
#   'token_str': 'desayuno',
#   'sequence': 'quiero comer un desayuno'},
#  {'score': 0.004699637647718191,
#   'token': 5525,
#   'token_str': 'dulce',
#   'sequence': 'quiero comer un dulce'},
#  {'score': 0.004640154540538788,
#   'token': 12117,
#   'token_str': 'hueso',
#   'sequence': 'quiero comer un hueso'},
#  {'score': 0.004526016768068075,
#   'token': 5992,
#   'token_str': 'caballo',
#   'sequence': 'quiero comer un caballo'},
#  {'score': 0.0043535251170396805,
#   'token': 30114,
#   'token_str': 'monton',
#   'sequence': 'quiero comer un monton'},
#  {'score': 0.003951233346015215,
#   'token': 27965,
#   'token_str': 'panque',
#   'sequence': 'quiero comer un panque'},
#  {'score': 0.0038414429873228073,
#   'token': 10614,
#   'token_str': 'cafe',
#   'sequence': 'quiero comer un cafe'},
#  {'score': 0.0037613622844219208,
#   'token': 27230,
#   'token_str': 'asado',
#   'sequence': 'quiero comer un asado'},
#  {'score': 0.0030917772091925144,
#   'token': 1008,
#   'token_str': '.',
#   'sequence': 'quiero comer un.'},
#  {'score': 0.002817727392539382,
#   'token': 9660,
#   'token_str': 'queso',
#   'sequence': 'quiero comer un queso'},
#  {'score': 0.0027711279690265656,
#   'token': 1515,
#   'token_str': 'cono',
#   'sequence': 'quiero comer un cono'},
#  {'score': 0.0025711122434586287,
#   'token': 27238,
#   'token_str': 'cangrejo',
#   'sequence': 'quiero comer un cangrejo'},
#  {'score': 0.002451496198773384,
#   'token': 12609,
#   'token_str': 'pizza',
#   'sequence': 'quiero comer un pizza'},
#  {'score': 0.0024173459969460964,
#   'token': 15051,
#   'token_str': 'pato',
#   'sequence': 'quiero comer un pato'},
#  {'score': 0.0021987678483128548,
#   'token': 30253,
#   'token_str': 'puerco',
#   'sequence': 'quiero comer un puerco'},
#  {'score': 0.002192255575209856,
#   'token': 23996,
#   'token_str': 'cigarro',
#   'sequence': 'quiero comer un cigarro'},
#  {'score': 0.00212782621383667,
#   'token': 16121,
#   'token_str': 'cordero',
#   'sequence': 'quiero comer un cordero'},
#  {'score': 0.0020846338011324406,
#   'token': 1100,
#   'token_str': '"',
#   'sequence': 'quiero comer un "'},
#  {'score': 0.001984597649425268,
#   'token': 11051,
#   'token_str': 'vaso',
#   'sequence': 'quiero comer un vaso'},
#  {'score': 0.0019421265460550785,
#   'token': 9067,
#   'token_str': 'bebe',
#   'sequence': 'quiero comer un bebe'},
#  {'score': 0.0019207444274798036,
#   'token': 6389,
#   'token_str': 'animal',
#   'sequence': 'quiero comer un animal'},
#  {'score': 0.0019046441884711385,
#   'token': 10941,
#   'token_str': 'ave',
#   'sequence': 'quiero comer un ave'},
#  {'score': 0.00186394271440804,
#   'token': 29953,
#   'token_str': 'yogur',
#   'sequence': 'quiero comer un yogur'},
#  {'score': 0.0017923926934599876,
#   'token': 6722,
#   'token_str': 'bis',
#   'sequence': 'quiero comer un bis'},
#  {'score': 0.0017747734673321247,
#   'token': 1072,
#   'token_str': 'par',
#   'sequence': 'quiero comer un par'},
#  {'score': 0.0017519959947094321,
#   'token': 15947,
#   'token_str': 'insecto',
#   'sequence': 'quiero comer un insecto'},
#  {'score': 0.001723731285892427,
#   'token': 23416,
#   'token_str': 'bocad',
#   'sequence': 'quiero comer un bocad'},
#  {'score': 0.001698257983662188,
#   'token': 27389,
#   'token_str': 'chicle',
#   'sequence': 'quiero comer un chicle'},
#  {'score': 0.0016587390564382076,
#   'token': 11395,
#   'token_str': 'oso',
#   'sequence': 'quiero comer un oso'},
#  {'score': 0.0016448430251330137,
#   'token': 14462,
#   'token_str': 'cigarrillo',
#   'sequence': 'quiero comer un cigarrillo'},
#  {'score': 0.0015988879604265094,
#   'token': 30563,
#   'token_str': 'taco',
#   'sequence': 'quiero comer un taco'},
#  {'score': 0.0015560255851596594,
#   'token': 1274,
#   'token_str': 'buen',
#   'sequence': 'quiero comer un buen'},
#  {'score': 0.001502619474194944,
#   'token': 20808,
#   'token_str': 'hamburguesa',
#   'sequence': 'quiero comer un hamburguesa'},
#  {'score': 0.0015017950208857656,
#   'token': 1155,
#   'token_str': 'te',
#   'sequence': 'quiero comer un te'},
#  {'score': 0.00142806360963732,
#   'token': 16705,
#   'token_str': 'coco',
#   'sequence': 'quiero comer un coco'},
#  {'score': 0.001390408375300467,
#   'token': 2635,
#   'token_str': 'bol',
#   'sequence': 'quiero comer un bol'},
#  {'score': 0.001388763077557087,
#   'token': 23589,
#   'token_str': 'bicho',
#   'sequence': 'quiero comer un bicho'},
#  {'score': 0.001341747585684061,
#   'token': 2247,
#   'token_str': 'ta',
#   'sequence': 'quiero comer un ta'},
#  {'score': 0.0013127833371981978,
#   'token': 1628,
#   'token_str': 'solo',
#   'sequence': 'quiero comer un solo'},
#  {'score': 0.0012641637586057186,
#   'token': 7085,
#   'token_str': 'dia',
#   'sequence': 'quiero comer un dia'},
#  {'score': 0.0012409663759171963,
#   'token': 29823,
#   'token_str': 'sushi',
#   'sequence': 'quiero comer un sushi'},
#  {'score': 0.0012246526312083006,
#   'token': 1264,
#   'token_str': 'man',
#   'sequence': 'quiero comer un man'},
#  {'score': 0.0012110124807804823,
#   'token': 7373,
#   'token_str': 'restaurante',
#   'sequence': 'quiero comer un restaurante'},
#  {'score': 0.0011578076519072056,
#   'token': 18473,
#   'token_str': 'gallo',
#   'sequence': 'quiero comer un gallo'},
#  {'score': 0.0011356518371030688,
#   'token': 7231,
#   'token_str': 'leon',
#   'sequence': 'quiero comer un leon'},
#  {'score': 0.0011085503501817584,
#   'token': 18874,
#   'token_str': 'elefante',
#   'sequence': 'quiero comer un elefante'},
#  {'score': 0.0011043590493500233,
#   'token': 26688,
#   'token_str': 'cereal',
#   'sequence': 'quiero comer un cereal'},
#  {'score': 0.0010889944387599826,
#   'token': 6838,
#   'token_str': 'pene',
#   'sequence': 'quiero comer un pene'},
#  {'score': 0.0010866550728678703,
#   'token': 1139,
#   'token_str': '-',
#   'sequence': 'quiero comer un -'},
#  {'score': 0.0010728106135502458,
#   'token': 26806,
#   'token_str': 'ciervo',
#   'sequence': 'quiero comer un ciervo'},
#  {'score': 0.0010337402345612645,
#   'token': 5761,
#   'token_str': 'rico',
#   'sequence': 'quiero comer un rico'},
#  {'score': 0.0010268241167068481,
#   'token': 11109,
#   'token_str': 'fresco',
#   'sequence': 'quiero comer un fresco'},
#  {'score': 0.001026101759634912,
#   'token': 27188,
#   'token_str': 'caracol',
#   'sequence': 'quiero comer un caracol'},
#  {'score': 0.00102163793053478,
#   'token': 9311,
#   'token_str': 'camion',
#   'sequence': 'quiero comer un camion'},
#  {'score': 0.0010153946932405233,
#   'token': 8969,
#   'token_str': 'cuchillo',
#   'sequence': 'quiero comer un cuchillo'},
#  {'score': 0.0009735818020999432,
#   'token': 24182,
#   'token_str': 'galleta',
#   'sequence': 'quiero comer un galleta'},
#  {'score': 0.0009457941632717848,
#   'token': 17805,
#   'token_str': 'cubo',
#   'sequence': 'quiero comer un cubo'},
#  {'score': 0.0009236038313247263,
#   'token': 22776,
#   'token_str': 'gatito',
#   'sequence': 'quiero comer un gatito'},
#  {'score': 0.0008924743160605431,
#   'token': 29726,
#   'token_str': 'pajarito',
#   'sequence': 'quiero comer un pajarito'},
#  {'score': 0.0008921739063225687,
#   'token': 29277,
#   'token_str': 'hongo',
#   'sequence': 'quiero comer un hongo'},
#  {'score': 0.0008836000924929976,
#   'token': 12323,
#   'token_str': 'rayo',
#   'sequence': 'quiero comer un rayo'},
#  {'score': 0.0008736724266782403,
#   'token': 1744,
#   'token_str': 'hombre',
#   'sequence': 'quiero comer un hombre'},
#  {'score': 0.0008716571610420942,
#   'token': 27291,
#   'token_str': 'dinosaurio',
#   'sequence': 'quiero comer un dinosaurio'},
#  {'score': 0.0008616280974820256,
#   'token': 23027,
#   'token_str': 'arbol',
#   'sequence': 'quiero comer un arbol'},
#  {'score': 0.0008504861034452915,
#   'token': 5122,
#   'token_str': 'carajo',
#   'sequence': 'quiero comer un carajo'},
#  {'score': 0.0008413463365286589,
#   'token': 11384,
#   'token_str': 'mani',
#   'sequence': 'quiero comer un mani'},
#  {'score': 0.000840857857838273,
#   'token': 8552,
#   'token_str': 'paquete',
#   'sequence': 'quiero comer un paquete'},
#  {'score': 0.0008278582827188075,
#   'token': 13906,
#   'token_str': 'tigre',
#   'sequence': 'quiero comer un tigre'},
#  {'score': 0.0008147973567247391,
#   'token': 8761,
#   'token_str': 'monstruo',
#   'sequence': 'quiero comer un monstruo'},
#  {'score': 0.0008097189129330218,
#   'token': 3172,
#   'token_str': 'chico',
#   'sequence': 'quiero comer un chico'},
#  {'score': 0.0008027558797039092,
#   'token': 17432,
#   'token_str': 'vegetal',
#   'sequence': 'quiero comer un vegetal'},
#  {'score': 0.0007851882837712765,
#   'token': 14456,
#   'token_str': 'chiste',
#   'sequence': 'quiero comer un chiste'},
#  {'score': 0.0007617773953825235,
#   'token': 27340,
#   'token_str': 'camaro',
#   'sequence': 'quiero comer un camaro'},
#  {'score': 0.0007617061492055655,
#   'token': 20056,
#   'token_str': 'tomate',
#   'sequence': 'quiero comer un tomate'},
#  {'score': 0.00075725611532107,
#   'token': 2880,
#   'token_str': 'grande',
#   'sequence': 'quiero comer un grande'},
#  {'score': 0.0007550325826741755,
#   'token': 7814,
#   'token_str': 'paseo',
#   'sequence': 'quiero comer un paseo'},
#  {'score': 0.0007423920906148851,
#   'token': 27017,
#   'token_str': 'picnic',
#   'sequence': 'quiero comer un picnic'},
#  {'score': 0.0007323961472138762,
#   'token': 1414,
#   'token_str': 'gran',
#   'sequence': 'quiero comer un gran'},
#  {'score': 0.0007309454376809299,
#   'token': 4415,
#   'token_str': 'error',
#   'sequence': 'quiero comer un error'},
#  {'score': 0.0007303970050998032,
#   'token': 2777,
#   'token_str': 'largo',
#   'sequence': 'quiero comer un largo'},
#  {'score': 0.0007301177829504013,
#   'token': 14369,
#   'token_str': 'delicioso',
#   'sequence': 'quiero comer un delicioso'},
#  {'score': 0.0007279388373717666,
#   'token': 6089,
#   'token_str': 'regalo',
#   'sequence': 'quiero comer un regalo'},
#  {'score': 0.0007253055809997022,
#   'token': 13726,
#   'token_str': 'manzana',
#   'sequence': 'quiero comer un manzana'},
#  {'score': 0.000719326373655349,
#   'token': 30010,
#   'token_str': 'sapo',
#   'sequence': 'quiero comer un sapo'},
#  {'score': 0.0006907634087838233,
#   'token': 7922,
#   'token_str': 'polvo',
#   'sequence': 'quiero comer un polvo'},
#  {'score': 0.0006904014735482633,
#   'token': 11804,
#   'token_str': 'flan',
#   'sequence': 'quiero comer un flan'},
#  {'score': 0.0006848422926850617,
#   'token': 7623,
#   'token_str': 'chip',
#   'sequence': 'quiero comer un chip'},
#  {'score': 0.0006773569621145725,
#   'token': 2934,
#   'token_str': 'juego',
#   'sequence': 'quiero comer un juego'},
#  {'score': 0.0006730513996444643,
#   'token': 3213,
#   'token_str': 'libro',
#   'sequence': 'quiero comer un libro'},
#  {'score': 0.0006644020322710276,
#   'token': 8373,
#   'token_str': 'chino',
#   'sequence': 'quiero comer un chino'},
#  {'score': 0.0006577116437256336,
#   'token': 10497,
#   'token_str': 'arroz',
#   'sequence': 'quiero comer un arroz'},
#  {'score': 0.0006538943853229284,
#   'token': 4215,
#   'token_str': 'negro',
#   'sequence': 'quiero comer un negro'},
#  {'score': 0.0006403476581908762,
#   'token': 25956,
#   'token_str': 'mango',
#   'sequence': 'quiero comer un mango'},
#  {'score': 0.0006331452168524265,
#   'token': 12845,
#   'token_str': 'grano',
#   'sequence': 'quiero comer un grano'},
#  {'score': 0.0006291643949225545,
#   'token': 28330,
#   'token_str': 'tenedor',
#   'sequence': 'quiero comer un tenedor'},
#  {'score': 0.0006246788543649018,
#   'token': 2950,
#   'token_str': 'pin',
#   'sequence': 'quiero comer un pin'},
#  {'score': 0.000614692980889231,
#   'token': 30765,
#   'token_str': 'lagarto',
#   'sequence': 'quiero comer un lagarto'},
#  {'score': 0.0006144529907032847,
#   'token': 13656,
#   'token_str': 'pino',
#   'sequence': 'quiero comer un pino'},
#  {'score': 0.0006122121121734381,
#   'token': 5673,
#   'token_str': 'papa',
#   'sequence': 'quiero comer un papa'},
#  {'score': 0.0006105987704358995,
#   'token': 16383,
#   'token_str': 'pajar',
#   'sequence': 'quiero comer un pajar'},
#  {'score': 0.0006104281637817621,
#   'token': 13350,
#   'token_str': 'toro',
#   'sequence': 'quiero comer un toro'},
#  {'score': 0.0005874991766177118,
#   'token': 7958,
#   'token_str': 'descanso',
#   'sequence': 'quiero comer un descanso'},
#  {'score': 0.000576240592636168,
#   'token': 12957,
#   'token_str': 'alimento',
#   'sequence': 'quiero comer un alimento'},
#  {'score': 0.000574825331568718,
#   'token': 17032,
#   'token_str': 'rollo',
#   'sequence': 'quiero comer un rollo'},
#  {'score': 0.0005716044688597322,
#   'token': 23612,
#   'token_str': 'lucio',
#   'sequence': 'quiero comer un lucio'},
#  {'score': 0.0005498041282407939,
#   'token': 1786,
#   'token_str': 'pla',
#   'sequence': 'quiero comer un pla'},
#  {'score': 0.0005490438197739422,
#   'token': 5971,
#   'token_str': 'aper',
#   'sequence': 'quiero comer un aper'},
#  {'score': 0.00054693385027349,
#   'token': 24293,
#   'token_str': 'frito',
#   'sequence': 'quiero comer un frito'},
#  {'score': 0.0005463612033054233,
#   'token': 2257,
#   'token_str': 'amigo',
#   'sequence': 'quiero comer un amigo'},
#  {'score': 0.0005461585242301226,
#   'token': 18041,
#   'token_str': 'ensalada',
#   'sequence': 'quiero comer un ensalada'},
#  {'score': 0.000543152098543942,
#   'token': 25277,
#   'token_str': 'cachorro',
#   'sequence': 'quiero comer un cachorro'},
#  {'score': 0.0005372738814912736,
#   'token': 1019,
#   'token_str': ',',
#   'sequence': 'quiero comer un,'},
#  {'score': 0.0005288388347253203,
#   'token': 1843,
#   'token_str': 'bus',
#   'sequence': 'quiero comer un bus'},
#  {'score': 0.0005091434577479959,
#   'token': 23532,
#   'token_str': 'pasto',
#   'sequence': 'quiero comer un pasto'},
#  {'score': 0.0004983250983059406,
#   'token': 12720,
#   'token_str': 'palo',
#   'sequence': 'quiero comer un palo'},
#  {'score': 0.00049192039296031,
#   'token': 29370,
#   'token_str': 'caldo',
#   'sequence': 'quiero comer un caldo'},
#  {'score': 0.0004907635156996548,
#   'token': 17545,
#   'token_str': 'tronco',
#   'sequence': 'quiero comer un tronco'},
#  {'score': 0.000489181315060705,
#   'token': 13177,
#   'token_str': 'naranja',
#   'sequence': 'quiero comer un naranja'},
#  {'score': 0.00048688420793041587,
#   'token': 1059,
#   'token_str': '?',
#   'sequence': 'quiero comer un?'},
#  {'score': 0.0004794041160494089,
#   'token': 17075,
#   'token_str': 'margarita',
#   'sequence': 'quiero comer un margarita'},
#  {'score': 0.00047657222603447735,
#   'token': 9717,
#   'token_str': 'bote',
#   'sequence': 'quiero comer un bote'},
#  {'score': 0.0004731943772640079,
#   'token': 12106,
#   'token_str': 'sopa',
#   'sequence': 'quiero comer un sopa'},
#  {'score': 0.0004710911598522216,
#   'token': 21640,
#   'token_str': 'pito',
#   'sequence': 'quiero comer un pito'},
#  {'score': 0.0004691059875767678,
#   'token': 1583,
#   'token_str': 'col',
#   'sequence': 'quiero comer un col'},
#  {'score': 0.0004576502542477101,
#   'token': 19332,
#   'token_str': 'bat',
#   'sequence': 'quiero comer un bat'},
#  {'score': 0.0004575917555484921,
#   'token': 10552,
#   'token_str': 'rio',
#   'sequence': 'quiero comer un rio'},
#  {'score': 0.00045655955909751356,
#   'token': 1404,
#   'token_str': 'ra',
#   'sequence': 'quiero comer un ra'},
#  {'score': 0.0004486713733058423,
#   'token': 1645,
#   'token_str': 'dios',
#   'sequence': 'quiero comer un dios'},
#  {'score': 0.0004430314293131232,
#   'token': 3051,
#   'token_str': 'ros',
#   'sequence': 'quiero comer un ros'},
#  {'score': 0.00044009211705997586,
#   'token': 14071,
#   'token_str': 'hot',
#   'sequence': 'quiero comer un hot'},
#  {'score': 0.00043873125105164945,
#   'token': 7985,
#   'token_str': 'angel',
#   'sequence': 'quiero comer un angel'},
#  {'score': 0.0004374678246676922,
#   'token': 18036,
#   'token_str': 'pay',
#   'sequence': 'quiero comer un pay'},
#  {'score': 0.0004341598541941494,
#   'token': 1827,
#   'token_str': 'nuevo',
#   'sequence': 'quiero comer un nuevo'},
#  {'score': 0.0004334805125836283,
#   'token': 9993,
#   'token_str': 'lobo',
#   'sequence': 'quiero comer un lobo'},
#  {'score': 0.00043196685146540403,
#   'token': 29554,
#   'token_str': 'cocodrilo',
#   'sequence': 'quiero comer un cocodrilo'},
#  {'score': 0.0004306846531108022,
#   'token': 3852,
#   'token_str': 'arma',
#   'sequence': 'quiero comer un arma'},
#  {'score': 0.00043046212522313,
#   'token': 3635,
#   'token_str': 'vino',
#   'sequence': 'quiero comer un vino'},
#  {'score': 0.00042996444972231984,
#   'token': 13219,
#   'token_str': 'triple',
#   'sequence': 'quiero comer un triple'},
#  {'score': 0.0004281670553609729,
#   'token': 2887,
#   'token_str': 'partido',
#   'sequence': 'quiero comer un partido'},
#  {'score': 0.0004241300921421498,
#   'token': 15612,
#   'token_str': 'dog',
#   'sequence': 'quiero comer un dog'},
#  {'score': 0.00042052436037920415,
#   'token': 24446,
#   'token_str': 'comi',
#   'sequence': 'quiero comer un comi'},
#  {'score': 0.0004199520335532725,
#   'token': 1915,
#   'token_str': 'momento',
#   'sequence': 'quiero comer un momento'},
#  {'score': 0.00041982909897342324,
#   'token': 4842,
#   'token_str': 'doble',
#   'sequence': 'quiero comer un doble'},
#  {'score': 0.0004114439361728728,
#   'token': 6172,
#   'token_str': 'mono',
#   'sequence': 'quiero comer un mono'},
#  {'score': 0.00040864114998839796,
#   'token': 10693,
#   'token_str': 'milagro',
#   'sequence': 'quiero comer un milagro'},
#  {'score': 0.00040574517333880067,
#   'token': 1054,
#   'token_str': 'no',
#   'sequence': 'quiero comer un no'},
#  {'score': 0.0004052316362503916,
#   'token': 17367,
#   'token_str': 'hoyo',
#   'sequence': 'quiero comer un hoyo'},
#  {'score': 0.00040298578096553683,
#   'token': 17695,
#   'token_str': 'tarta',
#   'sequence': 'quiero comer un tarta'},
#  {'score': 0.0003926399804186076,
#   'token': 8801,
#   'token_str': 'beso',
#   'sequence': 'quiero comer un beso'},
#  {'score': 0.00038915500044822693,
#   'token': 1109,
#   'token_str': '!',
#   'sequence': 'quiero comer un!'},
#  {'score': 0.0003863258461933583,
#   'token': 2905,
#   'token_str': 'pie',
#   'sequence': 'quiero comer un pie'},
#  {'score': 0.0003855056711472571,
#   'token': 6168,
#   'token_str': 'culo',
#   'sequence': 'quiero comer un culo'},
#  {'score': 0.00038507190765812993,
#   'token': 4789,
#   'token_str': 'chile',
#   'sequence': 'quiero comer un chile'},
#  {'score': 0.0003812334034591913,
#   'token': 4414,
#   'token_str': 'om',
#   'sequence': 'quiero comer un om'},
#  {'score': 0.0003802934370469302,
#   'token': 8640,
#   'token_str': 'taxi',
#   'sequence': 'quiero comer un taxi'},
#  {'score': 0.00036365212872624397,
#   'token': 10121,
#   'token_str': 'pico',
#   'sequence': 'quiero comer un pico'},
#  {'score': 0.0003588871331885457,
#   'token': 8937,
#   'token_str': 'demonio',
#   'sequence': 'quiero comer un demonio'},
#  {'score': 0.00035788246896117926,
#   'token': 15550,
#   'token_str': 'manhattan',
#   'sequence': 'quiero comer un manhattan'},
#  {'score': 0.0003548482491169125,
#   'token': 5269,
#   'token_str': 'pis',
#   'sequence': 'quiero comer un pis'},
#  {'score': 0.00035240122815594077,
#   'token': 15922,
#   'token_str': 'millon',
#   'sequence': 'quiero comer un millon'},
#  {'score': 0.0003498030418995768,
#   'token': 13663,
#   'token_str': 'globo',
#   'sequence': 'quiero comer un globo'},
#  {'score': 0.0003487418289296329,
#   'token': 28130,
#   'token_str': 'martini',
#   'sequence': 'quiero comer un martini'},
#  {'score': 0.0003467339847702533,
#   'token': 21101,
#   'token_str': 'crudo',
#   'sequence': 'quiero comer un crudo'},
#  {'score': 0.00034518627217039466,
#   'token': 8852,
#   'token_str': 'cuento',
#   'sequence': 'quiero comer un cuento'},
#  {'score': 0.00034073731512762606,
#   'token': 1601,
#   'token_str': 'go',
#   'sequence': 'quiero comer un go'},
#  {'score': 0.0003364042495377362,
#   'token': 10912,
#   'token_str': 'puro',
#   'sequence': 'quiero comer un puro'},
#  {'score': 0.0003318791277706623,
#   'token': 12979,
#   'token_str': 'robot',
#   'sequence': 'quiero comer un robot'},
#  {'score': 0.00033121847081929445,
#   'token': 4433,
#   'token_str': 'maldito',
#   'sequence': 'quiero comer un maldito'},
#  {'score': 0.00033048581099137664,
#   'token': 4059,
#   'token_str': 'cielo',
#   'sequence': 'quiero comer un cielo'},
#  {'score': 0.00032942145480774343,
#   'token': 6856,
#   'token_str': 'trasero',
#   'sequence': 'quiero comer un trasero'},
#  {'score': 0.0003281937970314175,
#   'token': 23013,
#   'token_str': 'torta',
#   'sequence': 'quiero comer un torta'},
#  {'score': 0.00032554229255765676,
#   'token': 1265,
#   'token_str': 'mar',
#   'sequence': 'quiero comer un mar'}]

# %% [markdown]
# Use function to benchmark speed

# %% [markdown]
# # Pipeline for app

# %% [markdown]
# We will first def a function to extract the predicted words. Then we will def a function to delete from the predicted words those who are not in our pictograms. Finally, we will def a function to get the k most likely words. The pipeline will be model_output -> extract_predicted_words() -> filter_according_to_pictograms() -> get_top_k_predictions()

# %% [markdown]
# Def extract_predicted_words

# %%
"this can be improved with a list comprehension"
predicted_words = []
def extract_predicted_words(unmasked, predicted_words):
  for unmask in unmasked:
    predicted_words.append(unmask['token_str'])
  return predicted_words


predicted_words = extract_predicted_words(unmasked, predicted_words)

predicted_words, len(predicted_words)
# Out:
# (['helado',
#   'filete',
#   'huevo',
#   'pastel',
#   'pollo',
#   'plato',
#   'poco',
#   'cerdo',
#   'conejo',
#   'pavo',
#   'pez',
#   'postre',
#   'trago',
#   'refresco',
#   'pescado',
#   'pedazo',
#   'perrito',
#   'perro',
#   'trozo',
#   'chocolate',
#   'gato',
#   'gusano',
#   'almuerzo',
#   'pan',
#   'caramelo',
#   'rato',
#   '[UNK]',
#   'poquito',
#   'desayuno',
#   'dulce',
#   'hueso',
#   'caballo',
#   'monton',
#   'panque',
#   'cafe',
#   'asado',
#   '.',
#   'queso',
#   'cono',
#   'cangrejo',
#   'pizza',
#   'pato',
#   'puerco',
#   'cigarro',
#   'cordero',
#   '"',
#   'vaso',
#   'bebe',
#   'animal',
#   'ave',
#   'yogur',
#   'bis',
#   'par',
#   'insecto',
#   'bocad',
#   'chicle',
#   'oso',
#   'cigarrillo',
#   'taco',
#   'buen',
#   'hamburguesa',
#   'te',
#   'coco',
#   'bol',
#   'bicho',
#   'ta',
#   'solo',
#   'dia',
#   'sushi',
#   'man',
#   'restaurante',
#   'gallo',
#   'leon',
#   'elefante',
#   'cereal',
#   'pene',
#   '-',
#   'ciervo',
#   'rico',
#   'fresco',
#   'caracol',
#   'camion',
#   'cuchillo',
#   'galleta',
#   'cubo',
#   'gatito',
#   'pajarito',
#   'hongo',
#   'rayo',
#   'hombre',
#   'dinosaurio',
#   'arbol',
#   'carajo',
#   'mani',
#   'paquete',
#   'tigre',
#   'monstruo',
#   'chico',
#   'vegetal',
#   'chiste',
#   'camaro',
#   'tomate',
#   'grande',
#   'paseo',
#   'picnic',
#   'gran',
#   'error',
#   'largo',
#   'delicioso',
#   'regalo',
#   'manzana',
#   'sapo',
#   'polvo',
#   'flan',
#   'chip',
#   'juego',
#   'libro',
#   'chino',
#   'arroz',
#   'negro',
#   'mango',
#   'grano',
#   'tenedor',
#   'pin',
#   'lagarto',
#   'pino',
#   'papa',
#   'pajar',
#   'toro',
#   'descanso',
#   'alimento',
#   'rollo',
#   'lucio',
#   'pla',
#   'aper',
#   'frito',
#   'amigo',
#   'ensalada',
#   'cachorro',
#   ',',
#   'bus',
#   'pasto',
#   'palo',
#   'caldo',
#   'tronco',
#   'naranja',
#   '?',
#   'margarita',
#   'bote',
#   'sopa',
#   'pito',
#   'col',
#   'bat',
#   'rio',
#   'ra',
#   'dios',
#   'ros',
#   'hot',
#   'angel',
#   'pay',
#   'nuevo',
#   'lobo',
#   'cocodrilo',
#   'arma',
#   'vino',
#   'triple',
#   'partido',
#   'dog',
#   'comi',
#   'momento',
#   'doble',
#   'mono',
#   'milagro',
#   'no',
#   'hoyo',
#   'tarta',
#   'beso',
#   '!',
#   'pie',
#   'culo',
#   'chile',
#   'om',
#   'taxi',
#   'pico',
#   'demonio',
#   'manhattan',
#   'pis',
#   'millon',
#   'globo',
#   'martini',
#   'crudo',
#   'cuento',
#   'go',
#   'puro',
#   'robot',
#   'maldito',
#   'cielo',
#   'trasero',
#   'torta',
#   'mar'],
#  200)

# %% [markdown]
# Def filter_according_to_pictograms()

# %%
pictograms_set = set(pictograms)


def filter_according_to_pictograms_set(predicted_words):
  predicted_words[:] = [word for word in predicted_words if word in pictograms_set]
  return predicted_words


filtered_pictograms = filter_according_to_pictograms_set(predicted_words)

# %% [markdown]
# def get_top_k_predictions()

# %%
def get_top_k_predictions(filtered_pictograms, k):
  if len(filtered_pictograms) > k:
    top_k_predictions = dict(zip(filtered_pictograms[:k], [unmasked[score]['score'] for score in range(len(filtered_pictograms[:k]))]))
  else:
    top_k_predictions = dict(zip(filtered_pictograms, [unmasked[score]['score'] for score in range(len(filtered_pictograms))]))
  return top_k_predictions

top_k_predictions = get_top_k_predictions(filtered_pictograms, 8)

top_k_predictions
# Out:
# {'helado': 0.10666672140359879,
#  'huevo': 0.07054208219051361,
#  'pollo': 0.0675901249051094,
#  'poco': 0.06573796272277832,
#  'cerdo': 0.047738898545503616,
#  'conejo': 0.04623118042945862,
#  'pez': 0.03755443915724754,
#  'pescado': 0.03274385258555412}

# %% [markdown]
# We wrap the whole pipeline in an app (i.e., def fill_mask())

# %%
import gradio as gr
from transformers import pipeline

top_k = 1000 #@param {type: "integer"}

unmasker = pipeline("fill-mask", model="franfram/distillbert-base-spanish-uncased_finetuned_with-Llama2-Knowledge-Distillation")

def fill_mask(text):
  text += ' [MASK]'
  unmasked = unmasker(text, top_k=top_k)
  predicted_words = []
  predicted_words = extract_predicted_words(unmasked, predicted_words)
  filtered_pictograms = filter_according_to_pictograms_set(predicted_words)
  top_k_predictions = get_top_k_predictions(filtered_pictograms, 8)
  return top_k_predictions

examples = [["quiero comer "], ["me gustaría ir a"], ["yo"]]

demo = gr.Interface(fn=fill_mask, inputs=gr.Textbox(lines=1, label="Input"), outputs=gr.Label(label="Output"), examples=examples)
demo.launch(debug=True, share=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://653f62264a27cc76f2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://653f62264a27cc76f2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /usr/local/lib/python3.10/dist-packages/gradio/components/button.py:89: UserWarning: Using the update method is deprecated. Simply return a new object instead, e.g. `return gr.Button(...)` instead of `return gr.Button.update(...)`.
#   warnings.warn(

# %% [markdown]
# # Using contexts

# %% [markdown]
# For this part, we will filter the predicted words according to another variable, i.e., the 'context' that is provided, which in turn will filter the output according to a list of pictograms contained in a given 'context'

# %% [markdown]
# First, we will download the contexts from a github repo, and inspect it a little bit.

# %%
import os.path
from os import path

# download 'contextos' file
if not path.exists("contextos2.json"):
  # !wget "https://raw.githubusercontent.com/franfram/Transformers-nlp/main/contextos2.json"


# open 'contextos' file
import json
with open("contextos2.json") as archivo:
  contextos = json.load(archivo)
# Out:
# --2023-10-03 13:04:40--  https://raw.githubusercontent.com/franfram/Transformers-nlp/main/contextos2.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22078 (22K) [text/plain]
# Saving to: ‘contextos2.json’
#
# contextos2.json     100%[===================>]  21.56K  --.-KB/s    in 0.006s
#
# 2023-10-03 13:04:40 (3.72 MB/s) - ‘contextos2.json’ saved [22078/22078]

# %% [markdown]
# Now, all the pictograms are contained within 'contexts'

# %%
contextos
# Out:
# {'desayuno': ['desayuno',
#   'comida',
#   'huevo',
#   'manteca',
#   'torta',
#   'tostada',
#   'mermelada',
#   'azúcar',
#   'beber',
#   'tomar',
#   'comer',
#   'cocinar',
#   'sucio',
#   'dulce',
#   'salado',
#   'duro',
#   'feo',
#   'mucho',
#   'más',
#   'lleno',
#   'poco',
#   'menos',
#   'agua',
#   'jugo de naranja',
#   'leche',
#   'café',
#   'té',
#   'mate',
#   'yogur',
#   'naranja',
#   'frutilla',
#   'banana',
#   'cerezas',
#   'manzana',
#   'mandarina',
#   'pera',
#   'mañana',
#   'despúes',
#   'hola',
#   'buenos días',
#   'adiós',
#   'es gracioso',
#   'buen provecho',
#   'yo también',
#   'estoy bien',
#   'abrelatas',
#   'aburrido',
#   'acercar',
#   'agarrar',
#   'agitar',
#   'agregar',
#   'agua',
#   'soda',
#   'alacena',
#   'alfajor',
#   'almendra',
#   'amargo',
#   'anana',
#   'apagar',
#   'aparato',
#   'apretar',
#   'aquella',
#   'aquellas',
#   'arándano',
#   'asco',
#   'asqueroso'],
#  'almuerzo': ['comida',
#   'ensalada',
#   'arroz',
#   'lentejas',
#   'canelones',
#   'pure',
#   'papa',
#   'zapallo',
#   'verduras',
#   'huevo',
#   'tortilla',
#   'sopa',
#   'carne',
#   'salchicha',
#   'hamburguesa',
#   'pollo',
#   'pizza',
#   'pan',
#   'queso',
#   'pescado',
#   'tomate',
#   'caramelo',
#   'sal',
#   'manteca',
#   'agua',
#   'coca cola',
#   'fanta',
#   'naranja',
#   'frutilla',
#   'limón',
#   'banana',
#   'melón',
#   'cerezas',
#   'manzana',
#   'mandarina',
#   'sandía',
#   'pera',
#   'sucio',
#   'dulce',
#   'salado',
#   'duro',
#   'feo',
#   'mucho',
#   'más',
#   'lleno',
#   'poco',
#   'menos',
#   'despúes',
#   'hola',
#   'adios',
#   'chau',
#   'es gracioso',
#   'buen provecho',
#   'yo también',
#   'estoy bien',
#   '¿cómo estas?',
#   'buenisimo',
#   'ya está',
#   'por favor',
#   'gracias',
#   'me gusta',
#   'no me gusta',
#   'quiero',
#   'yo',
#   'tú',
#   'amiga',
#   'amigo',
#   'abuela',
#   'abuelo',
#   'hermana',
#   'hermano',
#   'tío',
#   'tía',
#   'mamá',
#   'papá',
#   'nene',
#   'nena',
#   'mesa',
#   'cama',
#   'sillón',
#   'boca',
#   'dientes',
#   'lengua',
#   'barriga',
#   'casa',
#   'bar',
#   'restaurante',
#   'pizzería',
#   'comedor',
#   'habitación',
#   'cocina',
#   'patio',
#   'caliente',
#   'frío',
#   'dolor',
#   'enojado',
#   'contento',
#   'triste',
#   'beber',
#   'tomar',
#   'comer',
#   'cocinar'],
#  'merienda': ['desayuno',
#   'comida',
#   'huevo',
#   'manteca',
#   'torta',
#   'tostada',
#   'mermelada',
#   'azúcar',
#   'beber',
#   'tomar',
#   'comer',
#   'cocinar',
#   'sucio',
#   'dulce',
#   'salado',
#   'duro',
#   'feo',
#   'mucho',
#   'más',
#   'lleno',
#   'poco',
#   'menos',
#   'agua',
#   'jugo de naranja',
#   'leche',
#   'café',
#   'té',
#   'mate',
#   'yogur',
#   'naranja',
#   'frutilla',
#   'banana',
#   'cerezas',
#   'manzana',
#   'mandarina',
#   'pera',
#   'mañana',
#   'despúes',
#   'hola',
#   'buenos días',
#   'adiós',
#   'es gracioso',
#   'buen provecho',
#   'yo también',
#   'estoy bien',
#   'abrelatas',
#   'aburrido',
#   'acercar',
#   'agarrar',
#   'agitar',
#   'agregar',
#   'agua',
#   'soda',
#   'alacena',
#   'alfajor',
#   'almendra',
#   'amargo',
#   'anana',
#   'apagar',
#   'aparato',
#   'apretar',
#   'aquella',
#   'aquellas',
#   'arándano',
#   'asco',
#   'asqueroso'],
#  'cena': ['comida',
#   'ensalada',
#   'arroz',
#   'lentejas',
#   'canelones',
#   'pure',
#   'papa',
#   'zapallo',
#   'verduras',
#   'huevo',
#   'tortilla',
#   'sopa',
#   'carne',
#   'salchicha',
#   'hamburguesa',
#   'pollo',
#   'pizza',
#   'pan',
#   'queso',
#   'pescado',
#   'tomate',
#   'caramelo',
#   'sal',
#   'manteca',
#   'agua',
#   'coca cola',
#   'fanta',
#   'naranja',
#   'frutilla',
#   'limón',
#   'banana',
#   'melón',
#   'cerezas',
#   'manzana',
#   'mandarina',
#   'sandía',
#   'pera',
#   'sucio',
#   'dulce',
#   'salado',
#   'duro',
#   'feo',
#   'mucho',
#   'más',
#   'lleno',
#   'poco',
#   'menos',
#   'despúes',
#   'hola',
#   'adios',
#   'chau',
#   'es gracioso',
#   'buen provecho',
#   'yo también',
#   'estoy bien',
#   '¿cómo estas?',
#   'buenisimo',
#   'ya está',
#   'por favor',
#   'gracias',
#   'me gusta',
#   'no me gusta',
#   'quiero',
#   'yo',
#   'tú',
#   'amiga',
#   'amigo',
#   'abuela',
#   'abuelo',
#   'hermana',
#   'hermano',
#   'tío',
#   'tía',
#   'mamá',
#   'papá',
#   'nene',
#   'nena',
#   'mesa',
#   'cama',
#   'sillón',
#   'boca',
#   'dientes',
#   'lengua',
#   'barriga',
#   'casa',
#   'bar',
#   'restaurante',
#   'pizzería',
#   'comedor',
#   'habitación',
#   'cocina',
#   'patio',
#   'caliente',
#   'frío',
#   'dolor',
#   'enojado',
#   'contento',
#   'triste',
#   'beber',
#   'tomar',
#   'comer',
#   'cocinar'],
#  'aseo': ['cambiar',
#   'desvestir',
#   'vestir',
#   'bañar',
#   'secar',
#   'peinar',
#   'mojar',
#   'hacer pis',
#   'hacer caca',
#   'limpiar',
#   'poner',
#   'cortar',
#   'limpio',
#   'sucio',
#   'mojado',
#   'seco',
#   'flojo',
#   'más',
#   'menos',
#   'hola',
#   'adios',
#   'estoy bien',
#   '¿cómo estás?',
#   'buenísimo',
#   'ya está',
#   'ayuda',
#   'por favor',
#   'gracias',
#   'no toques',
#   'me gusta',
#   'no me gusta',
#   'no quiero',
#   'quiero',
#   'yo',
#   'tú',
#   'mamá',
#   'papá',
#   'silla',
#   'silla de ruedas',
#   'camilla',
#   'cabeza',
#   'cara',
#   'pelo',
#   'nariz',
#   'ojo',
#   'boca',
#   'dientes',
#   'lengua',
#   'oreja',
#   'cuello',
#   'cadera',
#   'espalda',
#   'brazo',
#   'panza',
#   'barriga',
#   'culo',
#   'vagina',
#   'pene',
#   'pierna',
#   'pie',
#   'dedo',
#   'mano',
#   'uña',
#   'piel',
#   'sangre',
#   'remera',
#   'buzo',
#   'campera',
#   'pantalones',
#   'vestido',
#   'falda',
#   'zapatos',
#   'botas',
#   'medias',
#   'camisa',
#   'babero',
#   'pijama',
#   'pañal',
#   'bombacha',
#   'calzoncillo',
#   'corpiño',
#   'cierre',
#   'botón',
#   'cinto',
#   'casa',
#   'residencia',
#   'escuela',
#   'bar',
#   'restaurante',
#   'hotel',
#   'hospital',
#   'camping',
#   'pileta',
#   'habitación',
#   'caliente',
#   'frío',
#   'dolor',
#   'enojado',
#   'contento',
#   'cansado',
#   'triste',
#   'incomodo'],
#  'descanso': ['hablar',
#   'contar',
#   'agarrar',
#   'cambiar',
#   'beber',
#   'tomar',
#   'dormir',
#   'ir',
#   'levantarse',
#   'acostarse',
#   'sentarse',
#   'dar',
#   'desvestir',
#   'vestir',
#   'limpiar',
#   'poner',
#   'cerrar',
#   'besar',
#   'escuchar',
#   'reír',
#   'ayudar',
#   'gustar',
#   'rascar',
#   'descansar',
#   'esperar',
#   'abrazar',
#   'molestar',
#   'bueno',
#   'limpio',
#   'sucio',
#   'encendido',
#   'apagado',
#   'oscuro',
#   'lindo',
#   'raro',
#   'duro',
#   'mojado',
#   'roto',
#   'seco',
#   'difícil',
#   'flojo',
#   'mucho',
#   'más',
#   'menos',
#   'agua',
#   'mañana',
#   'tarde',
#   'noche',
#   'buenas noches',
#   'adios',
#   'chau',
#   'es gracioso',
#   'yo también',
#   'estoy bien',
#   'buenísimo',
#   'es una tontería',
#   'ya está',
#   'ayuda',
#   'por favor',
#   'gracias',
#   'no toques',
#   'lo siento',
#   'me gusta',
#   'no me gusta',
#   'te quiero',
#   'no quiero',
#   'quiero',
#   'no lo entiendo',
#   'otro',
#   'yo',
#   'vos',
#   'abuelos',
#   'ellos',
#   'hermana',
#   'hermano',
#   'mamá',
#   'papá',
#   'nosotros',
#   '¿qué hacemos?',
#   '¿qué?',
#   '¿a qué hora?',
#   '¿por qué?',
#   '¿dónde?',
#   'sillón',
#   'cama',
#   'ventana',
#   'puerta',
#   'lámpara',
#   'luz',
#   'camilla',
#   'reloj',
#   'comunicador',
#   'televisor',
#   'libro',
#   'cuento',
#   'cabeza',
#   'cara',
#   'pelo',
#   'nariz',
#   'ojo',
#   'boca',
#   'dientes',
#   'lengua',
#   'cuello',
#   'cadera',
#   'espalda',
#   'brazo',
#   'barriga',
#   'culo',
#   'pierna',
#   'pie',
#   'mano',
#   'piel',
#   'sangre',
#   'cuerpo',
#   'remera',
#   'pantalones',
#   'vestido',
#   'zapatos',
#   'medias',
#   'babero',
#   'pijama',
#   'pañal',
#   'bombacha',
#   'calzoncillo',
#   'corpiño',
#   'cierrre',
#   'botón',
#   'ropa',
#   'abajo',
#   'arriba',
#   'cerca',
#   'lejos',
#   'calor',
#   'caliente',
#   'frío',
#   'miedo',
#   'asustado',
#   'dolor',
#   'enfermo',
#   'mareado',
#   'paciencia',
#   'enojado',
#   'contento',
#   'cansado',
#   'triste',
#   'incomodo',
#   'nervioso'],
#  'escuela': ['jugar',
#   'trabajar',
#   'escribir',
#   'leer',
#   'hablar',
#   'contar',
#   'estudiar',
#   'explicar',
#   'pintar',
#   'beber',
#   'comer',
#   'enseñar',
#   'ir',
#   'sentarse',
#   'caminar',
#   'correr',
#   'bailar',
#   'saltar',
#   'dar',
#   'subir',
#   'guardar',
#   'bajar',
#   'hacer',
#   'cantar',
#   'ordenar',
#   'llevar',
#   'cortar',
#   'romper',
#   'abrir',
#   'cerrar',
#   'mirar',
#   'escuchar',
#   'pensar',
#   'reir',
#   'llorar',
#   'besar',
#   'tener',
#   'olvidar',
#   'recordar',
#   'aprender',
#   'gustar',
#   'ayudar',
#   'saber',
#   'pelear',
#   'descansar',
#   'festejar',
#   'perder',
#   'ganar',
#   'esperar',
#   'abrazar',
#   'invitar',
#   'gritar',
#   'molestar',
#   'bueno',
#   'malo',
#   'rápido',
#   'claro',
#   'lento',
#   'roto',
#   'fácil',
#   'diferente',
#   'difícil',
#   'mucho',
#   'más',
#   'poco',
#   'merienda',
#   'desayuno',
#   'agua',
#   'jugo',
#   'mañana',
#   'tarde',
#   'ayer',
#   'hoy',
#   'pronto',
#   'después',
#   'día',
#   'mes',
#   'año',
#   'verano',
#   'otoño',
#   'invierno',
#   'primavera',
#   'sol',
#   'nubes',
#   'lluvia',
#   'hola',
#   'buenos días',
#   'buenas tardes',
#   'adios',
#   'es gracioso',
#   'yo también',
#   'estoy bien',
#   '¿cómo estás?',
#   '¿cómo te llamas?',
#   'buenísimo',
#   'es una tonteria',
#   'de acuerdo',
#   'ya está',
#   'equivocado',
#   'ayuda',
#   'por favor',
#   'gracias',
#   'no toques',
#   'felicidades',
#   'lo siento',
#   'me gusta',
#   'no me gusta',
#   'te quiero',
#   'no me gusta',
#   'no quiero',
#   'quiero',
#   'mala suerte',
#   'no lo sé',
#   'no lo entiendo',
#   'quiero ir a',
#   'yo',
#   'vos',
#   'amiga',
#   'amigo',
#   'maestra',
#   'maestro',
#   'ellos',
#   'nene',
#   'nena',
#   'niños',
#   'nosotros',
#   'compañero',
#   'compañera',
#   '¿qué hacemos?',
#   '¿qué?',
#   '¿cuántos?',
#   '¿cómo?',
#   '¿a qué hora?',
#   '¿cuándo?',
#   '¿quién?',
#   '¿para qué sirve?',
#   '¿por qué?',
#   '¿de quién?',
#   '¿dónde?',
#   'silla',
#   'silla de ruedas',
#   'mesa',
#   'estantería',
#   'ventana',
#   'luz',
#   'bipedestador',
#   'reloj',
#   'comunicador',
#   'computadora',
#   'timbre',
#   'tablero',
#   'cosa',
#   'lápiz',
#   'pintura',
#   'pincel',
#   'pizarrón',
#   'papel',
#   'libro',
#   'cuento',
#   'calendario',
#   'agenda',
#   'tijera',
#   'plastilina',
#   'carpeta',
#   'pegamento',
#   'dibujo',
#   'mochila',
#   'dinero',
#   'pelota',
#   'hamaca',
#   'tobogán',
#   'recreo',
#   'auto',
#   'colectivo',
#   'transporte escolar',
#   'cabeza',
#   'espalda',
#   'cuerpo',
#   'uniforme escolar',
#   'guardapolvo',
#   'ropa',
#   'buzo',
#   'campera',
#   'bufanda',
#   'guantes',
#   'gorro',
#   'pañal',
#   'taller',
#   'escuela',
#   'baño',
#   'clase',
#   'gimnasio',
#   'comedor',
#   'patio',
#   'escalera',
#   'ascensor',
#   'rampa',
#   'aula escolar',
#   'sala de jardín',
#   'cerca',
#   'lejos',
#   'adelante',
#   'entre',
#   'atras',
#   'al lado',
#   'adentro',
#   'afuera',
#   'sobre',
#   'abajo',
#   'izquierda',
#   'derecha',
#   'primero',
#   'último',
#   'arriba',
#   'divertido',
#   'aburrido',
#   'calor',
#   'caliente',
#   'frío',
#   'miedo',
#   'asustado',
#   'dolor',
#   'enfermo',
#   'mareado',
#   'sorprendido',
#   'paciencia',
#   'enojado',
#   'contento',
#   'cansado',
#   'triste',
#   'nervioso',
#   'incómodo',
#   'globo',
#   'regalo',
#   'cumpleaños',
#   'lápiz',
#   'pizarrón',
#   'plastilina',
#   'pincel',
#   'carpeta',
#   'agenda',
#   'papel',
#   'deberes',
#   'premio',
#   'vacaciones',
#   'clase de matemáticas',
#   'recreo',
#   'aprender',
#   'maestro',
#   'maestra',
#   'aula',
#   'dibujo',
#   'terminar',
#   'escribir',
#   'rompecabezas',
#   'pegamento',
#   'estudiar',
#   'saber',
#   'clasificar',
#   'libro',
#   'colegio',
#   'pegar',
#   'cortar',
#   'contar',
#   'pasar lista',
#   'comedor',
#   'leer',
#   'trabajar',
#   'estudiar'],
#  'juego': ['jugar',
#   'escribir',
#   'leer',
#   'hablar',
#   'contar',
#   'explicar',
#   'agarrar',
#   'pintar',
#   'cambiar',
#   'ir',
#   'sentarse',
#   'correr',
#   'bailar',
#   'saltar',
#   'dar',
#   'subir',
#   'guardar',
#   'esconder',
#   'bajar',
#   'hacer',
#   'mojar',
#   'cantar',
#   'dibujar',
#   'ordenar',
#   'romper',
#   'escuchar',
#   'reír',
#   'llorar',
#   'amar',
#   'besar',
#   'querer',
#   'tener',
#   'olvidar',
#   'recordar',
#   'aprender',
#   'gustar',
#   'ayudar',
#   'saber',
#   'pelear',
#   'festejar',
#   'perder',
#   'ganar',
#   'esperar',
#   'abrazar',
#   'invitar',
#   'gritar',
#   'fácil',
#   'difícil',
#   'nada',
#   'mucho',
#   'más',
#   'menos',
#   'poco',
#   'mañana',
#   'tarde',
#   'noche',
#   'ayer',
#   'hoy',
#   'despúes',
#   'lluvia',
#   'nubes',
#   'arco iris',
#   'hola',
#   'buenos días',
#   'buenas tardes',
#   'buenas noches',
#   'adios',
#   'chau',
#   'es gracioso',
#   'yo tambien',
#   'estoy bien',
#   '¿cómo estas?',
#   '¿cómo te llamas?',
#   'buenísimo',
#   'es una tontería',
#   'de acuerdo',
#   'ya está',
#   'por favor',
#   'gracias',
#   'no toques',
#   'lo siento',
#   'me gusta',
#   'no me gusta',
#   'te quiero',
#   'no quiero',
#   'no lo se',
#   'no lo entiendo',
#   'otro',
#   '¿querés jugar?',
#   '¿a qué jugamos?',
#   'yo también',
#   'vos',
#   'amiga',
#   'amigo',
#   'maestra',
#   'maestro',
#   'abuelos',
#   'ellos'],
#  'celebraciones': ['regalo',
#   'cumpleaños',
#   'carnaval',
#   'halloween',
#   'año nuevo',
#   'papá noel',
#   'ceyes magos',
#   'casamiento',
#   'día de la madre',
#   'día del padre',
#   'bengala',
#   'novio',
#   'novia',
#   'adorno',
#   'invitación',
#   'fiesta de la espuma',
#   'regalo',
#   'san valentín',
#   'cita',
#   'descanso',
#   'picnic',
#   'navidad',
#   'almuerzo',
#   'comida',
#   'merienda',
#   'festejar',
#   'decorar',
#   'abrir un regalo',
#   'envoltorio',
#   'paquete',
#   'desayuno',
#   'cena',
#   'guirnalda',
#   'encender',
#   'apagar',
#   'vela',
#   'soplar',
#   'asado',
#   'carta',
#   'esperar',
#   'invitar',
#   'asustar',
#   'regalar',
#   'golosinas',
#   'brindar',
#   'turrón',
#   'chocolate',
#   'pan dulce',
#   'comer',
#   'noche',
#   'disfrazar',
#   'guitarra',
#   'cantar',
#   'maquillar',
#   'Fuegos artificiales',
#   'mamá',
#   'papá',
#   'hermano',
#   'hermana',
#   'abuelo',
#   'abuela',
#   'amigo',
#   'amiga',
#   'amigos',
#   'torta',
#   'helado',
#   'hamburguesa',
#   'pizza',
#   'musica',
#   'jugar',
#   'globos',
#   'piñata',
#   'coca cola',
#   'fanta',
#   'agua',
#   'jugo',
#   'quiero',
#   'no quiero'],
#  'terapias': ['fonoaudiología',
#   'psicopedagogía',
#   'psicología',
#   'terapia ocupacional',
#   'musicoterapia',
#   'kinesiología',
#   'psicomotricista',
#   'terapia de grupo',
#   'terapia de pareja',
#   'médico',
#   'médica',
#   'enfermero',
#   'enfermera',
#   'buenos dias',
#   'buenas tardes',
#   'hola',
#   'adios',
#   'chau',
#   '¿cómo estas?',
#   'es gracioso',
#   'yo también',
#   'estoy bien',
#   'es una tonteria',
#   'de acuerdo',
#   'ya está',
#   'ayuda',
#   'genial',
#   'por favor',
#   'gracias',
#   'me gusta',
#   'no me gusta',
#   'te quiero',
#   'no lo se',
#   'no lo entiendo']}

# %% [markdown]
# And this 'contextos' object is a dictionary containing 10 context keys, which in turn contain a list of the given pictograms of a context.

# %%
contextos.keys(), len(contextos.keys()), type(contextos['desayuno'])
# Out:
# (dict_keys(['desayuno', 'almuerzo', 'merienda', 'cena', 'aseo', 'descanso', 'escuela', 'juego', 'celebraciones', 'terapias']),
#  10,
#  list)

# %% [markdown]
# Since 'contextos' contains compound words, we will have to wrangle the data a little bit so that we don't have compound words anymore.

# %%
import re

# def split_contextos(contextos):
#   return {k: ' '.join(contextos[k]).split(' ') for k, v in contextos.items()}



def split_contextos(contextos):
  return {k: set(re.findall(r"[\w']+|[.,!?;]", ' '.join(contextos[k]))) for k, v in contextos.items()}



contextos_split = split_contextos(contextos)
contextos_split
# Out:
# {'desayuno': {'abrelatas',
#   'aburrido',
#   'acercar',
#   'adiós',
#   'agarrar',
#   'agitar',
#   'agregar',
#   'agua',
#   'alacena',
#   'alfajor',
#   'almendra',
#   'amargo',
#   'anana',
#   'apagar',
#   'aparato',
#   'apretar',
#   'aquella',
#   'aquellas',
#   'arándano',
#   'asco',
#   'asqueroso',
#   'azúcar',
#   'banana',
#   'beber',
#   'bien',
#   'buen',
#   'buenos',
#   'café',
#   'cerezas',
#   'cocinar',
#   'comer',
#   'comida',
#   'de',
#   'desayuno',
#   'despúes',
#   'dulce',
#   'duro',
#   'días',
#   'es',
#   'estoy',
#   'feo',
#   'frutilla',
#   'gracioso',
#   'hola',
#   'huevo',
#   'jugo',
#   'leche',
#   'lleno',
#   'mandarina',
#   'manteca',
#   'manzana',
#   'mate',
#   'mañana',
#   'menos',
#   'mermelada',
#   'mucho',
#   'más',
#   'naranja',
#   'pera',
#   'poco',
#   'provecho',
#   'salado',
#   'soda',
#   'sucio',
#   'también',
#   'tomar',
#   'torta',
#   'tostada',
#   'té',
#   'yo',
#   'yogur'},
#  'almuerzo': {'?',
#   'abuela',
#   'abuelo',
#   'adios',
#   'agua',
#   'amiga',
#   'amigo',
#   'arroz',
#   'banana',
#   'bar',
#   'barriga',
#   'beber',
#   'bien',
#   'boca',
#   'buen',
#   'buenisimo',
#   'caliente',
#   'cama',
#   'canelones',
#   'caramelo',
#   'carne',
#   'casa',
#   'cerezas',
#   'chau',
#   'coca',
#   'cocina',
#   'cocinar',
#   'cola',
#   'comedor',
#   'comer',
#   'comida',
#   'contento',
#   'cómo',
#   'despúes',
#   'dientes',
#   'dolor',
#   'dulce',
#   'duro',
#   'enojado',
#   'ensalada',
#   'es',
#   'estas',
#   'estoy',
#   'está',
#   'fanta',
#   'favor',
#   'feo',
#   'frutilla',
#   'frío',
#   'gracias',
#   'gracioso',
#   'gusta',
#   'habitación',
#   'hamburguesa',
#   'hermana',
#   'hermano',
#   'hola',
#   'huevo',
#   'lengua',
#   'lentejas',
#   'limón',
#   'lleno',
#   'mamá',
#   'mandarina',
#   'manteca',
#   'manzana',
#   'me',
#   'melón',
#   'menos',
#   'mesa',
#   'mucho',
#   'más',
#   'naranja',
#   'nena',
#   'nene',
#   'no',
#   'pan',
#   'papa',
#   'papá',
#   'patio',
#   'pera',
#   'pescado',
#   'pizza',
#   'pizzería',
#   'poco',
#   'pollo',
#   'por',
#   'provecho',
#   'pure',
#   'queso',
#   'quiero',
#   'restaurante',
#   'sal',
#   'salado',
#   'salchicha',
#   'sandía',
#   'sillón',
#   'sopa',
#   'sucio',
#   'también',
#   'tomar',
#   'tomate',
#   'tortilla',
#   'triste',
#   'tía',
#   'tío',
#   'tú',
#   'verduras',
#   'ya',
#   'yo',
#   'zapallo'},
#  'merienda': {'abrelatas',
#   'aburrido',
#   'acercar',
#   'adiós',
#   'agarrar',
#   'agitar',
#   'agregar',
#   'agua',
#   'alacena',
#   'alfajor',
#   'almendra',
#   'amargo',
#   'anana',
#   'apagar',
#   'aparato',
#   'apretar',
#   'aquella',
#   'aquellas',
#   'arándano',
#   'asco',
#   'asqueroso',
#   'azúcar',
#   'banana',
#   'beber',
#   'bien',
#   'buen',
#   'buenos',
#   'café',
#   'cerezas',
#   'cocinar',
#   'comer',
#   'comida',
#   'de',
#   'desayuno',
#   'despúes',
#   'dulce',
#   'duro',
#   'días',
#   'es',
#   'estoy',
#   'feo',
#   'frutilla',
#   'gracioso',
#   'hola',
#   'huevo',
#   'jugo',
#   'leche',
#   'lleno',
#   'mandarina',
#   'manteca',
#   'manzana',
#   'mate',
#   'mañana',
#   'menos',
#   'mermelada',
#   'mucho',
#   'más',
#   'naranja',
#   'pera',
#   'poco',
#   'provecho',
#   'salado',
#   'soda',
#   'sucio',
#   'también',
#   'tomar',
#   'torta',
#   'tostada',
#   'té',
#   'yo',
#   'yogur'},
#  'cena': {'?',
#   'abuela',
#   'abuelo',
#   'adios',
#   'agua',
#   'amiga',
#   'amigo',
#   'arroz',
#   'banana',
#   'bar',
#   'barriga',
#   'beber',
#   'bien',
#   'boca',
#   'buen',
#   'buenisimo',
#   'caliente',
#   'cama',
#   'canelones',
#   'caramelo',
#   'carne',
#   'casa',
#   'cerezas',
#   'chau',
#   'coca',
#   'cocina',
#   'cocinar',
#   'cola',
#   'comedor',
#   'comer',
#   'comida',
#   'contento',
#   'cómo',
#   'despúes',
#   'dientes',
#   'dolor',
#   'dulce',
#   'duro',
#   'enojado',
#   'ensalada',
#   'es',
#   'estas',
#   'estoy',
#   'está',
#   'fanta',
#   'favor',
#   'feo',
#   'frutilla',
#   'frío',
#   'gracias',
#   'gracioso',
#   'gusta',
#   'habitación',
#   'hamburguesa',
#   'hermana',
#   'hermano',
#   'hola',
#   'huevo',
#   'lengua',
#   'lentejas',
#   'limón',
#   'lleno',
#   'mamá',
#   'mandarina',
#   'manteca',
#   'manzana',
#   'me',
#   'melón',
#   'menos',
#   'mesa',
#   'mucho',
#   'más',
#   'naranja',
#   'nena',
#   'nene',
#   'no',
#   'pan',
#   'papa',
#   'papá',
#   'patio',
#   'pera',
#   'pescado',
#   'pizza',
#   'pizzería',
#   'poco',
#   'pollo',
#   'por',
#   'provecho',
#   'pure',
#   'queso',
#   'quiero',
#   'restaurante',
#   'sal',
#   'salado',
#   'salchicha',
#   'sandía',
#   'sillón',
#   'sopa',
#   'sucio',
#   'también',
#   'tomar',
#   'tomate',
#   'tortilla',
#   'triste',
#   'tía',
#   'tío',
#   'tú',
#   'verduras',
#   'ya',
#   'yo',
#   'zapallo'},
#  'aseo': {'?',
#   'adios',
#   'ayuda',
#   'babero',
#   'bar',
#   'barriga',
#   'bañar',
#   'bien',
#   'boca',
#   'bombacha',
#   'botas',
#   'botón',
#   'brazo',
#   'buenísimo',
#   'buzo',
#   'cabeza',
#   'caca',
#   'cadera',
#   'caliente',
#   'calzoncillo',
#   'cambiar',
#   'camilla',
#   'camisa',
#   'campera',
#   'camping',
#   'cansado',
#   'cara',
#   'casa',
#   'cierre',
#   'cinto',
#   'contento',
#   'corpiño',
#   'cortar',
#   'cuello',
#   'culo',
#   'cómo',
#   'de',
#   'dedo',
#   'desvestir',
#   'dientes',
#   'dolor',
#   'enojado',
#   'escuela',
#   'espalda',
#   'estoy',
#   'está',
#   'estás',
#   'falda',
#   'favor',
#   'flojo',
#   'frío',
#   'gracias',
#   'gusta',
#   'habitación',
#   'hacer',
#   'hola',
#   'hospital',
#   'hotel',
#   'incomodo',
#   'lengua',
#   'limpiar',
#   'limpio',
#   'mamá',
#   'mano',
#   'me',
#   'medias',
#   'menos',
#   'mojado',
#   'mojar',
#   'más',
#   'nariz',
#   'no',
#   'ojo',
#   'oreja',
#   'pantalones',
#   'panza',
#   'papá',
#   'pañal',
#   'peinar',
#   'pelo',
#   'pene',
#   'pie',
#   'piel',
#   'pierna',
#   'pijama',
#   'pileta',
#   'pis',
#   'poner',
#   'por',
#   'quiero',
#   'remera',
#   'residencia',
#   'restaurante',
#   'ruedas',
#   'sangre',
#   'secar',
#   'seco',
#   'silla',
#   'sucio',
#   'toques',
#   'triste',
#   'tú',
#   'uña',
#   'vagina',
#   'vestido',
#   'vestir',
#   'ya',
#   'yo',
#   'zapatos'},
#  'descanso': {'?',
#   'a',
#   'abajo',
#   'abrazar',
#   'abuelos',
#   'acostarse',
#   'adios',
#   'agarrar',
#   'agua',
#   'apagado',
#   'arriba',
#   'asustado',
#   'ayuda',
#   'ayudar',
#   'babero',
#   'barriga',
#   'beber',
#   'besar',
#   'bien',
#   'boca',
#   'bombacha',
#   'botón',
#   'brazo',
#   'buenas',
#   'bueno',
#   'buenísimo',
#   'cabeza',
#   'cadera',
#   'caliente',
#   'calor',
#   'calzoncillo',
#   'cama',
#   'cambiar',
#   'camilla',
#   'cansado',
#   'cara',
#   'cerca',
#   'cerrar',
#   'chau',
#   'cierrre',
#   'comunicador',
#   'contar',
#   'contento',
#   'corpiño',
#   'cuello',
#   'cuento',
#   'cuerpo',
#   'culo',
#   'dar',
#   'descansar',
#   'desvestir',
#   'dientes',
#   'difícil',
#   'dolor',
#   'dormir',
#   'duro',
#   'dónde',
#   'ellos',
#   'encendido',
#   'enfermo',
#   'enojado',
#   'entiendo',
#   'es',
#   'escuchar',
#   'espalda',
#   'esperar',
#   'estoy',
#   'está',
#   'favor',
#   'flojo',
#   'frío',
#   'gracias',
#   'gracioso',
#   'gusta',
#   'gustar',
#   'hablar',
#   'hacemos',
#   'hermana',
#   'hermano',
#   'hora',
#   'incomodo',
#   'ir',
#   'lejos',
#   'lengua',
#   'levantarse',
#   'libro',
#   'limpiar',
#   'limpio',
#   'lindo',
#   'lo',
#   'luz',
#   'lámpara',
#   'mamá',
#   'mano',
#   'mareado',
#   'mañana',
#   'me',
#   'medias',
#   'menos',
#   'miedo',
#   'mojado',
#   'molestar',
#   'mucho',
#   'más',
#   'nariz',
#   'nervioso',
#   'no',
#   'noche',
#   'noches',
#   'nosotros',
#   'ojo',
#   'oscuro',
#   'otro',
#   'paciencia',
#   'pantalones',
#   'papá',
#   'pañal',
#   'pelo',
#   'pie',
#   'piel',
#   'pierna',
#   'pijama',
#   'poner',
#   'por',
#   'puerta',
#   'quiero',
#   'qué',
#   'raro',
#   'rascar',
#   'reloj',
#   'remera',
#   'reír',
#   'ropa',
#   'roto',
#   'sangre',
#   'seco',
#   'sentarse',
#   'siento',
#   'sillón',
#   'sucio',
#   'también',
#   'tarde',
#   'te',
#   'televisor',
#   'tomar',
#   'tontería',
#   'toques',
#   'triste',
#   'una',
#   'ventana',
#   'vestido',
#   'vestir',
#   'vos',
#   'ya',
#   'yo',
#   'zapatos'},
#  'escuela': {'?',
#   'a',
#   'abajo',
#   'abrazar',
#   'abrir',
#   'aburrido',
#   'acuerdo',
#   'adelante',
#   'adentro',
#   'adios',
#   'afuera',
#   'agenda',
#   'agua',
#   'al',
#   'amiga',
#   'amigo',
#   'aprender',
#   'arriba',
#   'ascensor',
#   'asustado',
#   'atras',
#   'aula',
#   'auto',
#   'ayer',
#   'ayuda',
#   'ayudar',
#   'año',
#   'bailar',
#   'bajar',
#   'baño',
#   'beber',
#   'besar',
#   'bien',
#   'bipedestador',
#   'buenas',
#   'bueno',
#   'buenos',
#   'buenísimo',
#   'bufanda',
#   'buzo',
#   'cabeza',
#   'calendario',
#   'caliente',
#   'calor',
#   'caminar',
#   'campera',
#   'cansado',
#   'cantar',
#   'carpeta',
#   'cerca',
#   'cerrar',
#   'claro',
#   'clase',
#   'clasificar',
#   'colectivo',
#   'colegio',
#   'comedor',
#   'comer',
#   'compañera',
#   'compañero',
#   'computadora',
#   'comunicador',
#   'contar',
#   'contento',
#   'correr',
#   'cortar',
#   'cosa',
#   'cuento',
#   'cuerpo',
#   'cumpleaños',
#   'cuándo',
#   'cuántos',
#   'cómo',
#   'dar',
#   'de',
#   'deberes',
#   'derecha',
#   'desayuno',
#   'descansar',
#   'después',
#   'dibujo',
#   'diferente',
#   'difícil',
#   'dinero',
#   'divertido',
#   'dolor',
#   'día',
#   'días',
#   'dónde',
#   'ellos',
#   'enfermo',
#   'enojado',
#   'enseñar',
#   'entiendo',
#   'entre',
#   'equivocado',
#   'es',
#   'escalera',
#   'escolar',
#   'escribir',
#   'escuchar',
#   'escuela',
#   'espalda',
#   'esperar',
#   'estantería',
#   'estoy',
#   'estudiar',
#   'está',
#   'estás',
#   'explicar',
#   'favor',
#   'felicidades',
#   'festejar',
#   'frío',
#   'fácil',
#   'ganar',
#   'gimnasio',
#   'globo',
#   'gorro',
#   'gracias',
#   'gracioso',
#   'gritar',
#   'guantes',
#   'guardapolvo',
#   'guardar',
#   'gusta',
#   'gustar',
#   'hablar',
#   'hacemos',
#   'hacer',
#   'hamaca',
#   'hola',
#   'hora',
#   'hoy',
#   'incómodo',
#   'invierno',
#   'invitar',
#   'ir',
#   'izquierda',
#   'jardín',
#   'jugar',
#   'jugo',
#   'lado',
#   'leer',
#   'lejos',
#   'lento',
#   'libro',
#   'lista',
#   'llamas',
#   'llevar',
#   'llorar',
#   'lluvia',
#   'lo',
#   'luz',
#   'lápiz',
#   'maestra',
#   'maestro',
#   'mala',
#   'malo',
#   'mareado',
#   'matemáticas',
#   'mañana',
#   'me',
#   'merienda',
#   'mes',
#   'mesa',
#   'miedo',
#   'mirar',
#   'mochila',
#   'molestar',
#   'mucho',
#   'más',
#   'nena',
#   'nene',
#   'nervioso',
#   'niños',
#   'no',
#   'nosotros',
#   'nubes',
#   'olvidar',
#   'ordenar',
#   'otoño',
#   'paciencia',
#   'papel',
#   'para',
#   'pasar',
#   'patio',
#   'pañal',
#   'pegamento',
#   'pegar',
#   'pelear',
#   'pelota',
#   'pensar',
#   'perder',
#   'pincel',
#   'pintar',
#   'pintura',
#   'pizarrón',
#   'plastilina',
#   'poco',
#   'por',
#   'premio',
#   'primavera',
#   'primero',
#   'pronto',
#   'quiero',
#   'quién',
#   'qué',
#   'rampa',
#   'recordar',
#   'recreo',
#   'regalo',
#   'reir',
#   'reloj',
#   'rompecabezas',
#   'romper',
#   'ropa',
#   'roto',
#   'ruedas',
#   'rápido',
#   'saber',
#   'sala',
#   'saltar',
#   'sentarse',
#   'siento',
#   'silla',
#   'sirve',
#   'sobre',
#   'sol',
#   'sorprendido',
#   'subir',
#   'suerte',
#   'sé',
#   'tablero',
#   'taller',
#   'también',
#   'tarde',
#   'tardes',
#   'te',
#   'tener',
#   'terminar',
#   'tijera',
#   'timbre',
#   'tobogán',
#   'tonteria',
#   'toques',
#   'trabajar',
#   'transporte',
#   'triste',
#   'una',
#   'uniforme',
#   'vacaciones',
#   'ventana',
#   'verano',
#   'vos',
#   'ya',
#   'yo',
#   'último'},
#  'juego': {'?',
#   'a',
#   'abrazar',
#   'abuelos',
#   'acuerdo',
#   'adios',
#   'agarrar',
#   'amar',
#   'amiga',
#   'amigo',
#   'aprender',
#   'arco',
#   'ayer',
#   'ayudar',
#   'bailar',
#   'bajar',
#   'besar',
#   'bien',
#   'buenas',
#   'buenos',
#   'buenísimo',
#   'cambiar',
#   'cantar',
#   'chau',
#   'contar',
#   'correr',
#   'cómo',
#   'dar',
#   'de',
#   'despúes',
#   'dibujar',
#   'difícil',
#   'días',
#   'ellos',
#   'entiendo',
#   'es',
#   'esconder',
#   'escribir',
#   'escuchar',
#   'esperar',
#   'estas',
#   'estoy',
#   'está',
#   'explicar',
#   'favor',
#   'festejar',
#   'fácil',
#   'ganar',
#   'gracias',
#   'gracioso',
#   'gritar',
#   'guardar',
#   'gusta',
#   'gustar',
#   'hablar',
#   'hacer',
#   'hola',
#   'hoy',
#   'invitar',
#   'ir',
#   'iris',
#   'jugamos',
#   'jugar',
#   'leer',
#   'llamas',
#   'llorar',
#   'lluvia',
#   'lo',
#   'maestra',
#   'maestro',
#   'mañana',
#   'me',
#   'menos',
#   'mojar',
#   'mucho',
#   'más',
#   'nada',
#   'no',
#   'noche',
#   'noches',
#   'nubes',
#   'olvidar',
#   'ordenar',
#   'otro',
#   'pelear',
#   'perder',
#   'pintar',
#   'poco',
#   'por',
#   'querer',
#   'querés',
#   'quiero',
#   'qué',
#   'recordar',
#   'reír',
#   'romper',
#   'saber',
#   'saltar',
#   'se',
#   'sentarse',
#   'siento',
#   'subir',
#   'tambien',
#   'también',
#   'tarde',
#   'tardes',
#   'te',
#   'tener',
#   'tontería',
#   'toques',
#   'una',
#   'vos',
#   'ya',
#   'yo'},
#  'celebraciones': {'Fuegos',
#   'abrir',
#   'abuela',
#   'abuelo',
#   'adorno',
#   'agua',
#   'almuerzo',
#   'amiga',
#   'amigo',
#   'amigos',
#   'apagar',
#   'artificiales',
#   'asado',
#   'asustar',
#   'año',
#   'bengala',
#   'brindar',
#   'cantar',
#   'carnaval',
#   'carta',
#   'casamiento',
#   'cena',
#   'ceyes',
#   'chocolate',
#   'cita',
#   'coca',
#   'cola',
#   'comer',
#   'comida',
#   'cumpleaños',
#   'de',
#   'decorar',
#   'del',
#   'desayuno',
#   'descanso',
#   'disfrazar',
#   'dulce',
#   'día',
#   'encender',
#   'envoltorio',
#   'esperar',
#   'espuma',
#   'fanta',
#   'festejar',
#   'fiesta',
#   'globos',
#   'golosinas',
#   'guirnalda',
#   'guitarra',
#   'halloween',
#   'hamburguesa',
#   'helado',
#   'hermana',
#   'hermano',
#   'invitación',
#   'invitar',
#   'jugar',
#   'jugo',
#   'la',
#   'madre',
#   'magos',
#   'mamá',
#   'maquillar',
#   'merienda',
#   'musica',
#   'navidad',
#   'no',
#   'noche',
#   'noel',
#   'novia',
#   'novio',
#   'nuevo',
#   'padre',
#   'pan',
#   'papá',
#   'paquete',
#   'picnic',
#   'pizza',
#   'piñata',
#   'quiero',
#   'regalar',
#   'regalo',
#   'san',
#   'soplar',
#   'torta',
#   'turrón',
#   'un',
#   'valentín',
#   'vela'},
#  'terapias': {'?',
#   'acuerdo',
#   'adios',
#   'ayuda',
#   'bien',
#   'buenas',
#   'buenos',
#   'chau',
#   'cómo',
#   'de',
#   'dias',
#   'enfermera',
#   'enfermero',
#   'entiendo',
#   'es',
#   'estas',
#   'estoy',
#   'está',
#   'favor',
#   'fonoaudiología',
#   'genial',
#   'gracias',
#   'gracioso',
#   'grupo',
#   'gusta',
#   'hola',
#   'kinesiología',
#   'lo',
#   'me',
#   'musicoterapia',
#   'médica',
#   'médico',
#   'no',
#   'ocupacional',
#   'pareja',
#   'por',
#   'psicología',
#   'psicomotricista',
#   'psicopedagogía',
#   'quiero',
#   'se',
#   'también',
#   'tardes',
#   'te',
#   'terapia',
#   'tonteria',
#   'una',
#   'ya',
#   'yo'}}

# %% [markdown]
# We will modify the `filter_according_to_pictograms` function to `filter_according_to_contexts`. To accomplish this, instead of filtering the output to match whole set of pictograms, we will filter the output to match the subset of pictograms contained in a given context (which will be another function argument)

# %% [markdown]
# We first extract the output of the model:

# %% [markdown]
# Now we create the `filter_according_to_contexts()` function

# %%
def filter_according_to_context(predicted_words, context):
  predicted_words[:] = [word for word in predicted_words if word in contextos_split[context]]
  return predicted_words

filtered_pictograms = filter_according_to_context(predicted_words, context = 'merienda')

# %% [markdown]
# ## Full pipeline app (with contexts)

# %%
test = list(contextos_split.keys())

test[1]
# Out:
# 'almuerzo'

# %%
import gradio as gr
from transformers import pipeline

top_k = 1000 #@param {type: "integer"}
text = "quiero " #@param {type: "string"}
context = "merienda" #@param {type: "string"}



unmasker = pipeline("fill-mask", model="franfram/distillbert-base-spanish-uncased_finetuned_with-Llama2-Knowledge-Distillation")

def fill_mask(text, context):
  text += ' [MASK]'
  unmasked = unmasker(text, top_k=top_k)
  predicted_words = []
  predicted_words = extract_predicted_words(unmasked, predicted_words)
  filtered_pictograms = filter_according_to_context(predicted_words, context)
  top_k_predictions = get_top_k_predictions(filtered_pictograms, 8)
  return top_k_predictions

examples = [["quiero comer "], ["me gustaría ir a"], ["yo"]]



# fill_mask(text, context)

# https://gradio.app/quickstart/
# demo = gr.Interface(
#     fn=fill_mask,
#     inputs=gr.Textbox(lines=1, label="text"),
#     outputs=gr.Label(label="Output"),
#     examples=examples
# )

# dict_keys(['desayuno', 'almuerzo', 'merienda', 'cena', 'aseo', 'descanso', 'escuela', 'juego', 'celebraciones', 'terapias']))

contexts = list(contextos_split.keys())


demo = gr.Interface(
    fn=fill_mask,
    inputs=[gr.Textbox(lines=1, label="text"), gr.Textbox(lines=1, label="context")],
    outputs=gr.Label(label="Output"),
    examples=[[examples[0], contexts[0]], [examples[1], contexts[1]]],
    #examples=[examples, contextos_split.keys()]
)
demo.launch(debug=True, share=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://e8c016b4c1ac06508d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e8c016b4c1ac06508d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://e8c016b4c1ac06508d.gradio.live
